# %% [markdown]
# # Load the Dataset

# %%
import pandas as pd

insurance_df = pd.read_csv("insurance.csv")


# Display the first few rows
print("Medical Cost Dataset")
display(insurance_df.head())
# Out:
# Medical Cost Dataset
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
print("Missing values in Medical Cost Dataset:")
print(insurance_df.isnull().sum())
# Out:
# Missing values in Medical Cost Dataset:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
print("Medical Cost Data Types:\n", insurance_df.dtypes)
# Out:
# Medical Cost Data Types:
#  age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
print("Medical Cost Dataset Statistics")
display(insurance_df.describe())
# Out:
# Medical Cost Dataset Statistics
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histograms for numerical features
insurance_df.hist(figsize=(12, 8), bins=30)
plt.show()

# Boxplots for outlier detection
plt.figure(figsize=(10, 6))
sns.boxplot(data=insurance_df)
plt.xticks(rotation=90)  # Rotate x labels for better visibility
plt.show()

# %%
print("Duplicates in Medical Cost Dataset:", insurance_df.duplicated().sum())
# Out:
# Duplicates in Medical Cost Dataset: 1

# %%
insurance_df.drop_duplicates(inplace=True)

# %%
print("Duplicates in Medical Cost Dataset:", insurance_df.duplicated().sum())
# Out:
# Duplicates in Medical Cost Dataset: 0

# %% [markdown]
# # Handle Missing Values

# %%
# Fill missing numerical values with median
insurance_df.fillna(insurance_df.select_dtypes(include=['number']).median(), inplace=True)

# %%
for col in insurance_df.select_dtypes(include=['object']).columns:
    insurance_df[col] = insurance_df[col].fillna(insurance_df[col].mode()[0])

# %% [markdown]
#  # Encoding Categorical Variables

# %%
from sklearn.preprocessing import OneHotEncoder

# One-hot encoding for categorical columns
insurance_df = pd.get_dummies(insurance_df, drop_first=True)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()  # Use MinMaxScaler() for min-max scaling

# Apply scaling

insurance_df.iloc[:, :-1] = scaler.fit_transform(insurance_df.iloc[:, :-1])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3992\565609051.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.44041773 -1.51164747 -0.79935006 ... -1.51164747 -1.29795825
#   1.55123139]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   insurance_df.iloc[:, :-1] = scaler.fit_transform(insurance_df.iloc[:, :-1])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3992\565609051.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.90923416 -0.07944162  1.58014347 ... -0.90923416 -0.90923416
#  -0.90923416]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   insurance_df.iloc[:, :-1] = scaler.fit_transform(insurance_df.iloc[:, :-1])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3992\565609051.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.00977099  0.99032355  0.99032355 ... -1.00977099 -1.00977099
#  -1.00977099]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   insurance_df.iloc[:, :-1] = scaler.fit_transform(insurance_df.iloc[:, :-1])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3992\565609051.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.96966039 -0.50770174 -0.50770174 ... -0.50770174 -0.50770174
#   1.96966039]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   insurance_df.iloc[:, :-1] = scaler.fit_transform(insurance_df.iloc[:, :-1])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3992\565609051.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.5655458  -0.5655458  -0.5655458  ... -0.5655458  -0.5655458
#   1.76820338]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   insurance_df.iloc[:, :-1] = scaler.fit_transform(insurance_df.iloc[:, :-1])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3992\565609051.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.61163774  1.63495472  1.63495472 ...  1.63495472 -0.61163774
#  -0.61163774]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   insurance_df.iloc[:, :-1] = scaler.fit_transform(insurance_df.iloc[:, :-1])

# %% [markdown]
# # Split Dataset into Train-Test Sets

# %%
from sklearn.model_selection import train_test_split



# Split Medical Cost Dataset
X_insurance = insurance_df.drop(columns=['charges'])
y_insurance = insurance_df['charges']
X_train_insurance, X_test_insurance, y_train_insurance, y_test_insurance = train_test_split(X_insurance, y_insurance, test_size=0.2, random_state=42)

# %% [markdown]
# # Apply Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

def evaluate_model(X_train, X_test, y_train, y_test):
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    return mae, mse, r2

# Test different train-test splits
splits = [0.3, 0.2, 0.1]

for split in splits:
    X_train, X_test, y_train, y_test = train_test_split(X_insurance, y_insurance, test_size=split, random_state=42)
    mae, mse, r2 = evaluate_model(X_train, X_test, y_train, y_test)
    print(f"Test Split {split}: MAE={mae}, MSE={mse}, R2={r2}")
# Out:
# Test Split 0.3: MAE=0.3454381895983668, MSE=0.2657104954574699, R2=0.7724363518631285
# Test Split 0.2: MAE=0.3450441318630676, MSE=0.24208632037687294, R2=0.8069287081198013
# Test Split 0.1: MAE=0.36032891501109243, MSE=0.2625189274385948, R2=0.78565585888308

# %%
train_sizes = [0.25, 0.5, 0.75, 1.0]
results = []

for size in train_sizes:
    X_train_sub = X_train_insurance[:int(size * len(X_train_insurance))]
    y_train_sub = y_train_insurance[:int(size * len(y_train_insurance))]
    
    mae, mse, r2 = evaluate_model(X_train_sub, X_test_insurance, y_train_sub, y_test_insurance)
    results.append((size, mae, mse, r2))

# Plot Results
sizes, maes, mses, r2s = zip(*results)
plt.plot(sizes, r2s, marker='o', label="R2 Score")
plt.xlabel("Dataset Size")
plt.ylabel("R2 Score")
plt.title("Effect of Dataset Size on Model Performance")
plt.legend()
plt.show()
